# %%
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
import csv
import locale
import numpy as np
import pandas as pd
import requests

# %%
/spain/andalucia/malaga
/spain/madrid
/spain/galicia/a-coruna

# %%
def generador_url():
    dias_meses = {
        1: 31,
        2: 28,
        3: 31,
        4: 30,
        5: 31,
        6: 30,
        7: 31,
        8: 31,
        9: 30,
        10: 31,
        11: 30,
        12: 31
    }
    urls_entero = []
    for mes, dia in dias_meses.items():
        for dia in range(1, dia + 1):
            url_base = f"https://www.tiempo3.com/europe/spain/madrid?page=past-weather#day={dia}&month={mes}"
            urls_entero.append(url_base)
        
    return urls_entero

# %%
generador_url()

# %%
#Primer funcion de PRUEBA

def extraer_datos():
    
    driver = webdriver.Chrome()
    
    for url in urls:
        
        driver.get(url)
        
        sleep(4)
        
        #Extracion 1er fila
        año_1 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(1) > td:nth-child(1) > span.year-link.link-button").text
        dia_1 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(1) > td:nth-child(1) > span.hide").text
        temp_max_1 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(1) > td.fourteen_day > span.day-max-temp > span:nth-child(1)").text
        temp_min_1 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(1) > td.fourteen_day > span.day-min-temp > span:nth-child(1)").text
        lluvia_1 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(1) > td:nth-child(3) > span:nth-child(1)").text
        tiempo_1 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(1) > td.hide.left-align").text
        viento_1 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(1) > td:nth-child(6) > span:nth-child(1)").text
        
        #Extracion 2da fila
        año_2 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(2) > td:nth-child(1) > span.year-link.link-button").text
        dia_2 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(2) > td:nth-child(1) > span.hide").text
        temp_max_2 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(2) > td.fourteen_day > span.day-max-temp > span:nth-child(1)").text
        temp_min_2 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(2) > td.fourteen_day > span.day-min-temp > span:nth-child(1)").text
        lluvia_2 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(2) > td:nth-child(3) > span:nth-child(1)").text
        tiempo_2 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(2) > td.hide.left-align").text
        viento_2 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(2) > td:nth-child(6) > span:nth-child(1)").text
        
        #Extracion 3er fila
        año_3 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(3) > td:nth-child(1) > span.year-link.link-button").text
        dia_3 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(3) > td:nth-child(1) > span.hide").text
        temp_max_3 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(3) > td.fourteen_day > span.day-max-temp > span:nth-child(1)").text
        temp_min_3 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(3) > td.fourteen_day > span.day-min-temp > span:nth-child(1)").text
        lluvia_3 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(3) > td:nth-child(3) > span:nth-child(1)").text
        tiempo_3 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(3) > td.hide.left-align").text
        viento_3 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(3) > td:nth-child(6) > span:nth-child(1)").text
        
        #Extracion 4ta fila
        año_4 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(4) > td:nth-child(1) > span.year-link.link-button").text
        dia_4 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(4) > td:nth-child(1) > span.hide").text
        temp_max_4 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(4) > td.fourteen_day > span.day-max-temp > span:nth-child(1)").text
        temp_min_4 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(4) > td.fourteen_day > span.day-min-temp > span:nth-child(1)").text
        lluvia_4 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(4) > td:nth-child(3) > span:nth-child(1)").text
        tiempo_4 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(4) > td.hide.left-align").text
        viento_4 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(4) > td:nth-child(6) > span:nth-child(1)").text
        
        #Extracion 5ta fila                                         
        año_5 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(5) > td:nth-child(1) > span.year-link.link-button").text
        dia_5 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(5) > td:nth-child(1) > span.hide").text
        temp_max_5 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(5) > td.fourteen_day > span.day-max-temp > span:nth-child(1)").text
        temp_min_5 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(5) > td.fourteen_day > span.day-min-temp > span:nth-child(1)").text
        lluvia_5 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(5) > td:nth-child(3) > span:nth-child(1)").text
        tiempo_5 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(5) > td.hide.left-align").text
        viento_5 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(5) > td:nth-child(6) > span:nth-child(1)").text
        
        #Extracion 6ta fila (NO FUNCIONA DESPUES DEL DIA ACTUAL)
        año_6 = driver.find_element(by = By.XPATH, value = '//*[@id="years-table"]/div/table/tbody/tr[6]/td[1]/span[1]').text
        dia_6 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(6) > td:nth-child(1) > span.hide").text
        temp_max_6 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(6) > td.fourteen_day > span.day-max-temp > span:nth-child(1)").text
        temp_min_6 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(6) > td.fourteen_day > span.day-min-temp > span:nth-child(1)").text
        lluvia_6 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(6) > td:nth-child(3) > span:nth-child(1)").text
        tiempo_6 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(6) > td.hide.left-align").text
        viento_6 = driver.find_element(by = By.CSS_SELECTOR, value = "#years-table > div > table > tbody > tr:nth-child(6) > td:nth-child(6) > span:nth-child(1)").text
        
        #Limpieza datos 1er fila:
        dia_1 = dia_1.replace("- ", "")
        lluvia_1 = lluvia_1 + " mm"
        viento_1 = viento_1 + " Km/h"
        
        #Limpieza datos 2da fila:
        dia_2 = dia_2.replace("- ", "")
        lluvia_2 = lluvia_2 + " mm"
        viento_2 = viento_2 + " Km/h"
        
        #Limpieza datos 3er fila:
        dia_3 = dia_3.replace("- ", "")
        lluvia_3 = lluvia_3 + " mm"
        viento_3 = viento_3 + " Km/h"
        
        #Limpieza datos 4ta fila:
        dia_4 = dia_4.replace("- ", "")
        lluvia_4 = lluvia_4 + " mm"
        viento_4 = viento_4 + " Km/h"
        
        #Limpieza datos 5ta fila:
        dia_5 = dia_5.replace("- ", "")
        lluvia_5 = lluvia_5 + " mm"
        viento_5 = viento_5 + " Km/h"
        
        #Limpieza datos 6ta fila:
        dia_6 = dia_5.replace("- ", "")
        lluvia_6 = lluvia_6 + " mm"
        viento_6 = viento_6 + " Km/h"
        
        #Almacenando en listas
        
        fila_1 = [año_1, dia_1, temp_max_1, temp_min_1, lluvia_1, tiempo_1, viento_1]
        
        fila_2 = [año_2, dia_2, temp_max_2, temp_min_2, lluvia_2, tiempo_2, viento_2]
        
        fila_3 = [año_3, dia_3, temp_max_3, temp_min_3, lluvia_3, tiempo_3, viento_3]
        
        fila_4 = [año_4, dia_4, temp_max_4, temp_min_4, lluvia_4, tiempo_4, viento_4]
        
        fila_5 = [año_5, dia_5, temp_max_5, temp_min_5, lluvia_5, tiempo_5, viento_5]
        
        fila_6 = [año_6, dia_6, temp_max_6, temp_min_6, lluvia_6, tiempo_6, viento_6]
        
        #Escritura de CSV:
        with open("extraccion-clima.csv", 'a', newline = '') as saver:
            escritor = csv.writer(saver)
            escritor.writerow(fila_1)
            escritor.writerow(fila_2)
            escritor.writerow(fila_3)
            escritor.writerow(fila_4)
            escritor.writerow(fila_5)
            escritor.writerow(fila_6)
            
        print(fila_1)
        print(fila_2)
        print(fila_3)
        print(fila_4)
        print(fila_5)
        print(fila_6)
        
            
    driver.close()
    driver.quit()

# %%
#Funcion optimizada para Scrap de fechas anteriores al dia actual

def extraer_datos_1():
    
    driver = webdriver.Chrome()
    
    for url in url_1_coruña:
        
        driver.get(url)
        
        sleep(4)
            
        #Extracion informacion
        for i in range(2, 7):
                
            año = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td:nth-child(1) > span.year-link.link-button").text
            dia = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td:nth-child(1) > span.hide").text
            temp_max = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td.fourteen_day > span.day-max-temp > span:nth-child(1)").text
            temp_min = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td.fourteen_day > span.day-min-temp > span:nth-child(1)").text
            lluvia = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td:nth-child(3) > span:nth-child(1)").text
            tiempo = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td.hide.left-align").text
            viento = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td:nth-child(6) > span:nth-child(1)").text
            ubicacion = driver.find_element(by = By.CSS_SELECTOR, value = "body > header > div.header-center-wrap > div.page-header").text
            
            #Limpieza datos 1er fila:
            dia = dia.replace("- ", "")
            lluvia = lluvia + " mm"
            viento = viento + " Km/h"
            fecha_str = dia + " " + año
            
            #Almacenando en listas
            fila = [fecha_str, temp_max, temp_min, lluvia, tiempo, viento, ubicacion]
            
            #Escritura de CSV:
            with open("extraccion-clima-coruña.csv", 'a', newline = '') as saver:
                escritor = csv.writer(saver)
                escritor.writerow(fila)
            
            print(fila)
            
            #driver.close()

# %% [markdown]
# Funcion definitiva funcional

# %%
def extraer_datos():
    
    driver = webdriver.Chrome()
    
    for url in url_madrid:
        try:
            driver.get(url)

            sleep(4)

            verificador = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({1}) > td:nth-child(1) > span.year-link.link-button").text
            
            #Extracion recuadro
            if verificador == "2024":
                for i in range(2, 7):
                
                    año = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td:nth-child(1) > span.year-link.link-button").text
                    dia = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td:nth-child(1) > span.hide").text
                    temp_max = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td.fourteen_day > span.day-max-temp > span:nth-child(1)").text
                    temp_min = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td.fourteen_day > span.day-min-temp > span:nth-child(1)").text
                    lluvia = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td:nth-child(3) > span:nth-child(1)").text
                    tiempo = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td.hide.left-align").text
                    viento = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td:nth-child(6) > span:nth-child(1)").text
                    ubicacion = driver.find_element(by = By.CSS_SELECTOR, value = "body > header > div.header-center-wrap > div.page-header").text
                    #Limpieza datos:
                    dia = dia.replace("- ", "")
                    lluvia = lluvia + " mm"
                    viento = viento + " Km/h"
                    fecha_str = dia + " " + año 
                    #Almacenando en listas
                    fila = [fecha_str, temp_max, temp_min, lluvia, tiempo, viento, ubicacion]   
                    #Escritura de CSV: (Aqui debe cambiarse el nombre del archivo con su ubicacion)
                    with open("extraccion-clima-madrid.csv", 'a', newline = '') as saver:
                        escritor = csv.writer(saver)
                        escritor.writerow(fila) 
                    print(fila)
            else:
                for i in range(1, 6):

                    año = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td:nth-child(1) > span.year-link.link-button").text
                    dia = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td:nth-child(1) > span.hide").text           
                    temp_max = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td.fourteen_day > span.day-max-temp > span:nth-child(1)").text          
                    temp_min = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td.fourteen_day > span.day-min-temp > span:nth-child(1)").text
                    lluvia = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td:nth-child(3) > span:nth-child(1)").text        
                    tiempo = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td.hide.left-align").text             
                    viento = driver.find_element(by = By.CSS_SELECTOR, value = f"#years-table > div > table > tbody > tr:nth-child({i}) > td:nth-child(6) > span:nth-child(1)").text             
                    ubicacion = driver.find_element(by = By.CSS_SELECTOR, value = "body > header > div.header-center-wrap > div.page-header").text  
                    #Limpieza datos:
                    dia = dia.replace("- ", "")
                    lluvia = lluvia + " mm"
                    viento = viento + " Km/h"
                    fecha_str = dia + " " + año 
                    #Almacenando en listas
                    fila = [fecha_str, temp_max, temp_min, lluvia, tiempo, viento, ubicacion]   
                    #Escritura de CSV: (Aqui debe cambiarse el nombre del archivo con su ubicacion)
                    with open("extraccion-clima-madrid.csv", 'a', newline = '') as saver:
                        escritor = csv.writer(saver)
                        escritor.writerow(fila) 
                    print(fila)

                    #driver.close()
        except:
            print("No hay datos")

# %%
#Ejecucion scrap
extraer_datos()
# Out:
# ['1 de enero 2023', '14', '6', '0 mm', 'Parcialmente nublado', '7 Km/h', 'Madrid']
# ['1 de enero 2022', '16', '7', '0 mm', 'Cielo cubierto', '6 Km/h', 'Madrid']
# ['1 de enero 2021', '5', '2', '2,8 mm', 'Nieve moderada a intervalos', '24 Km/h', 'Madrid']
# ['1 de enero 2020', '13', '8', '0 mm', 'Parcialmente nublado', '4 Km/h', 'Madrid']
# ['1 de enero 2019', '17', '8', '0 mm', 'Despejado', '5 Km/h', 'Madrid']
# ['2 de enero 2023', '13', '9', '1,1 mm', 'Llovizna a intervalos', '15 Km/h', 'Madrid']
# ['2 de enero 2022', '16', '8', '0 mm', 'Despejado', '5 Km/h', 'Madrid']
# ['2 de enero 2021', '5', '0', '0 mm', 'Nevadas ligeras a intervalos', '22 Km/h', 'Madrid']
# ['2 de enero 2020', '13', '7', '0 mm', 'Parcialmente nublado', '4 Km/h', 'Madrid']
# ['2 de enero 2019', '17', '6', '0 mm', 'Despejado', '5 Km/h', 'Madrid']
# ['3 de enero 2023', '13', '5', '0 mm', 'Despejado', '10 Km/h', 'Madrid']
# ['3 de enero 2022', '16', '7', '0 mm', 'Despejado', '4 Km/h', 'Madrid']
# ...
